# %%
import pandas as pd

# %%
wd = '/Users/danielmsheehan/GitHub/beh-gis.github.com/data/cartodb/'

varThemes = ['walkability-ct2010',
            'treecanopy-ct2010',
            'mhhi-ct2010',
            'alcohol-ct2010',
            'acstotpop-ct2010',
            'acspopden-ct2010',
            'acspctage65up-ct2010',
            'acspctpov-ct2010',
            'acspctblack-ct2010',
            'acspctasian-ct2010',
            'acspctunemploy-ct2010',
            'cnthomicide20032011-ct2010',
            'ratehomicide20032011-ct2010',
            'bikertlenall-ct2010',
            'pedkil19952013-ct2010',
            'pedinj19952013-ct2010',
            'bikkil19952013-ct2010',
            'bikinj19952013-ct2010',
            'cntcafeall-ct2010',
            'subwaystopdoittcount-ct2010'
            ]

varNames = ['Walkability',
            'Tree Canopy',
            'Median Household Income',
            'Off-Premise Alcohol Licenses',
            'ACS 2008-2012 Total Population',
            'ACS 2008-2012 Population Density-Land Area',
            'ACS 2008-2012 Percent Age 65 and Up', 
            'ACS 2008-2012 Percent in Poverty',
            'ACS 2008-2012 Percent Black',
            'ACS 2008-2012 Percent Asian',
            'ACS 2008-2012 Percent Unemployed',
            'Count Homicide 2003-2011/08 - NY Times',
            'Homicide Rate per 100,000 2003-2011/08 - NY Times',
            'Bike Routes Length',
            'Pedestrians Killed 1995-2013',
            'Pedestrians Injured 1995-2013',
            'Bicyclists Killed 1995-2013',
            'Bicyclists Injured 1995-2013',
            'Count Sidewalk Cafes - year?',
            'Count Subway Stops - DOITT'
            ]

vizIDs   = ['https://dms2203.cartodb.com/api/v2/viz/a7e9cb92-9b52-11e4-b578-0e9d821ea90d/viz.json',
            'https://dms2203.cartodb.com/api/v2/viz/8ea73f6c-ab1e-11e4-9f73-0e0c41326911/viz.json',
            'https://dms2203.cartodb.com/api/v2/viz/0a7e8122-ab38-11e4-9bff-0e853d047bba/viz.json',
            'https://dms2203.cartodb.com/api/v2_1/viz/b5f847d8-ab27-11e4-8da3-0e9d821ea90d/viz.json',
            'https://dms2203.cartodb.com/api/v2_1/viz/ff77ad9a-112f-11e5-8cda-0e018d66dc29/viz.json',
            'https://dms2203.cartodb.com/api/v2_1/viz/c280e8ba-1130-11e5-a711-0e853d047bba/viz.json',
            'https://dms2203.cartodb.com/api/v2_1/viz/5f774dda-1131-11e5-ae9f-0e9d821ea90d/viz.json',
            'https://dms2203.cartodb.com/api/v2_1/viz/97a28b88-1132-11e5-b041-0e853d047bba/viz.json',
            'https://dms2203.cartodb.com/api/v2_1/viz/0e3ff5c8-1133-11e5-bdf9-0e018d66dc29/viz.json',
            'https://dms2203.cartodb.com/api/v2_1/viz/65906592-1133-11e5-bf47-0e4fddd5de28/viz.json',
            'https://dms2203.cartodb.com/api/v2_1/viz/d5a9d624-1133-11e5-9a03-0e853d047bba/viz.json',
            'https://dms2203.cartodb.com/api/v2_1/viz/212b5294-1134-11e5-bfc1-0e9d821ea90d/viz.json',
            'https://dms2203.cartodb.com/api/v2_1/viz/73e19822-1134-11e5-bb5b-0e0c41326911/viz.json',
            'https://dms2203.cartodb.com/api/v2_1/viz/b6469276-1134-11e5-8928-0e4fddd5de28/viz.json',
            'https://dms2203.cartodb.com/api/v2_1/viz/e1dc5754-1134-11e5-8bf5-0e4fddd5de28/viz.json', #LAST HERE
            'https://dms2203.cartodb.com/api/v2_1/viz/b5f847d8-ab27-11e4-8da3-0e9d821ea90d/viz.json',
            'https://dms2203.cartodb.com/api/v2_1/viz/b5f847d8-ab27-11e4-8da3-0e9d821ea90d/viz.json',
            'https://dms2203.cartodb.com/api/v2_1/viz/b5f847d8-ab27-11e4-8da3-0e9d821ea90d/viz.json',
            'https://dms2203.cartodb.com/api/v2_1/viz/b5f847d8-ab27-11e4-8da3-0e9d821ea90d/viz.json',
            'https://dms2203.cartodb.com/api/v2_1/viz/b5f847d8-ab27-11e4-8da3-0e9d821ea90d/viz.json'
            ]
    
api_pre = 'https://dms2203.cartodb.com/api/v2/sql?filename=beh_'
    
theVars = [['t10_key','t10_km2','t10_lndkm2','t10_cnt','t10_resdn1','t10_intden','t10_entrpy','t10_rtlfar','t10_sub07d','t10_walk','t10_walk_c'],
           ]
    
            #varTheme.replace('-','_') + '&format=csv&q=SELECT geoid,' + theVar. ','.join() +  FROM nyct2010_walkability' or for others ct10
csvUrls = ['walkability_ct2010.csv&format=csv&q=SELECT geoid,t10_key,t10_km2,t10_lndkm2,t10_cnt,t10_resdn1,t10_intden,t10_entrpy,t10_rtlfar,t10_sub07d,t10_walk,t10_walk_c FROM nyct2010_walkability',
           'treecanopy_ct2010.csv&format=csv&q=SELECT geoid,cttreepct FROM ct10_tree_canopy',
           'mhhi_ct2010.csv&format=csv&q=SELECT geoid,t10_057001 FROM ct10_mhhi_acs_2006_2010',
           'alcohol_ct2010.csv&format=csv&q=SELECT geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'acstotpop_ct2010.csv&format=csv&q=SELECT geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'acspopden_ct2010.csv&format=csv&q=SELECT geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'acspctage65up_ct2010.csv&format=csv&q=SELECT geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'acspctpov_ct2010.csv&format=csv&q=SELECT geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'acspctblack_ct2010.csv&format=csv&q=SELECT geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'acspctasian_ct2010.csv&format=csv&q=SELECT geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'acspctunemploy_ct2010.csv&format=csv&q=SELECT geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'cnthomicide20032011_ct2010.csv&format=csv&q=SELECT geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'ratehomicide20032011_ct2010.csv&format=csv&q=SELECT geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'bikertlenall_ct2010.csv&format=csv&q=SELECT geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'pedkil19952013_ct2010.csv&format=csv&q=SELECT geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'pedinj19952013_ct2010.csv&format=csv&q=SELECT geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'bikkil19952013_ct2010.csv&format=csv&q=SELECT geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'bikinj19952013_ct2010.csv&format=csv&q=SELECT geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'cntcafeall_ct2010.csv&format=csv&q=SELECT geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'subwaystopdoittcount_ct2010.csv&format=csv&q=SELECT geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses'
           ]

            #varTheme.replace('-','_') + '&format=csv&q=SELECT the_geom,geoid,' + theVar. ','.join() +  FROM nyct2010_walkability' or for others ct10
shpUrls = ['walkability_ct2010&format=shp&q=SELECT the_geom,geoid,t10_key,t10_km2,t10_lndkm2,t10_cnt,t10_resdn1,t10_intden,t10_entrpy,t10_rtlfar,t10_sub07d,t10_walk,t10_walk_c FROM nyct2010_walkability',
           'treecanopy_ct2010&format=shp&q=SELECT the_geom,geoid,cttreepct FROM ct10_tree_canopy',
           'mhhi_ct2010&format=shp&q=SELECT the_geom,geoid,t10_057001 FROM ct10_mhhi_acs_2006_2010',
           'alcohol_ct2010&format=shp&q=SELECT the_geom,geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'acstotpop_ct2010&format=shp&q=SELECT the_geom,geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'acspopden_ct2010&format=shp&q=SELECT the_geom,geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'acspctage65up_ct2010&format=shp&q=SELECT the_geom,geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'acspctpov_ct2010&format=shp&q=SELECT the_geom,geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'acspctblack_ct2010&format=shp&q=SELECT the_geom,geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'acspctasian_ct2010&format=shp&q=SELECT the_geom,geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'acspctunemploy_ct2010&format=shp&q=SELECT the_geom,geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'cnthomicide20032011_ct2010&format=shp&q=SELECT the_geom,geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'ratehomicide20032011_ct2010&format=shp&q=SELECT the_geom,geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'bikertlenall_ct2010&format=shp&q=SELECT the_geom,geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'pedkil19952013_ct2010&format=shp&q=SELECT the_geom,geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'pedinj19952013_ct2010&format=shp&q=SELECT the_geom,geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'bikkil19952013_ct2010&format=shp&q=SELECT the_geom,geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'bikinj19952013_ct2010&format=shp&q=SELECT the_geom,geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'cntcafeall_ct2010&format=shp&q=SELECT the_geom,geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           'subwaystopdoittcount_ct2010&format=shp&q=SELECT the_geom,geoid,cdeligibil,ct10alcall,ct10alccl1,ct10alccl2 ,ct10alccl3,ct10alccl4,ct10alccl5 FROM ct10_alcohol_licenses',
           ]

# %%
dropdownStuff = []

for varTheme, varName in zip(varThemes, varNames):
    htmlText = '<li role="presentation"><a href="'+varTheme+'.html" id="'+varTheme+'" class="button '+varTheme+'">'+varName+'</a></li>'  
    dropdownStuff.append(htmlText)
    
dropdownHTML = ''.join(dropdownStuff)
print dropdownHTML
# Out:
# <li role="presentation"><a href="walkability-ct2010.html" id="walkability-ct2010" class="button walkability-ct2010">Walkability</a></li><li role="presentation"><a href="treecanopy-ct2010.html" id="treecanopy-ct2010" class="button treecanopy-ct2010">Tree Canopy</a></li><li role="presentation"><a href="mhhi-ct2010.html" id="mhhi-ct2010" class="button mhhi-ct2010">Median Household Income</a></li><li role="presentation"><a href="alcohol-ct2010.html" id="alcohol-ct2010" class="button alcohol-ct2010">Off-Premise Alcohol Licenses</a></li><li role="presentation"><a href="acstotpop-ct2010.html" id="acstotpop-ct2010" class="button acstotpop-ct2010">ACS 2008-2012 Total Population</a></li><li role="presentation"><a href="acspopden-ct2010.html" id="acspopden-ct2010" class="button acspopden-ct2010">ACS 2008-2012 Population Density-Land Area</a></li><li role="presentation"><a href="acspctage65up-ct2010.html" id="acspctage65up-ct2010" class="button acspctage65up-ct2010">ACS 2008-2012 Percent Age 65 
# ...

# %%
for varTheme,varName,vizID,csvUrl,shpUrl in zip(varThemes,varNames,vizIDs,csvUrls,shpUrls):
    dictUrl = '../../../data/dictionary/'+varTheme+'.html'
    
    html_str = '''<html>
    <head>
      <meta name="viewport" content="width=device-width, initial-scale=1">
      <link rel="stylesheet" href="http://maxcdn.bootstrapcdn.com/bootstrap/3.3.4/css/bootstrap.min.css">
      <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>
      <script src="http://maxcdn.bootstrapcdn.com/bootstrap/3.3.4/js/bootstrap.min.js"></script>
      <link rel="stylesheet" href="http://libs.cartocdn.com/cartodb.js/v3/3.11/themes/css/cartodb.css" />
      <script src="http://libs.cartocdn.com/cartodb.js/v3/3.11/cartodb.js"></script>
      <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js"></script>
      <script src="http://maxcdn.bootstrapcdn.com/bootstrap/3.3.4/js/bootstrap.min.js"></script>
      <link rel="stylesheet" href="http://maxcdn.bootstrapcdn.com/bootstrap/3.3.4/css/bootstrap.min.css">
      <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js"></script>
      <script src="http://maxcdn.bootstrapcdn.com/bootstrap/3.3.4/js/bootstrap.min.js"></script>
    
      <link rel="stylesheet" href="css/style.css">   <!-- LOCAL FILE -->
      <script src="js/'''+varTheme+'''_script.js"></script>   <!-- LOCAL FILE -->
    </head>
    
    <body onload="init()">
      <div id='map'></div>
      <!-- LEFT PANEL IS SAME FOR EVERY PAGE -->
      <div id="leftpanel">

        <button class="btn btn-default dropdown-toggle" type="button" id="menu1"><a href="../../../" class="button all">Home</a>
            </button>
            </br>
        <button class="btn btn-default dropdown-toggle" type="button" id="menu1"><a href="../cartodb" class="button all">Reset</a>
            </button>
    
          <div class="dropdown">
            <button class="btn btn-default dropdown-toggle" type="button" id="menu1" data-toggle="dropdown">Variables
            <span class="caret"></span></button>
            <ul class="dropdown-menu" role="menu" aria-labelledby="menu1">
              '''+dropdownHTML+'''
            </ul>
          </div>
        </div>
      </div>
      <!-- LEFT PANEL IS SAME FOR EVERY PAGE -->
      <div id='exports'>
          <p></p>
          <button onclick='location.href="'''+dictUrl+'''"'>'''+varName+''' <strong>Data dictionary</strong></button>
          <p></p>
          <button onclick='location.href="'''+api_pre+csvUrl+'''"'>Export '''+varName+''' data as <strong>CSV</strong></button>
          <p></p>
          <button onclick='location.href="'''+api_pre+shpUrl+'''"'>Export '''+varName+''' data as <strong>Shapefile</strong></button>
      </div>
    </body>
    </html>'''
    
    
    Html_file= open(wd+varTheme+'.html',"w")
    Html_file.write(html_str)
    Html_file.close()

# %%
for varTheme,varName,vizID,csvUrl,shpUrl in zip(varThemes,varNames,vizIDs,csvUrls,shpUrls):
    js_str = '''var map;
        function init(){
      // initiate leaflet map
      map = new L.Map('map', { 
        center: [40.705,-73.94], 
        zoom: 11
      })
      //L.tileLayer('https://dnv9my2eseobd.cloudfront.net/v3/cartodb.map-4xtxp73f/{z}/{x}/{y}.png', {
      //  attribution: 'Mapbox <a href="http://mapbox.com/about/maps" target="_blank">Terms &amp; Feedback</a>'
      //}).addTo(map);
      //L.tileLayer('http://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
      //    attribution: '&copy; <a href="http://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors'
      //}).addTo(map);
      L.tileLayer('http://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png', {
        attribution: '&copy; <a href="http://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors, &copy; <a href="http://cartodb.com/attributions">CartoDB</a>'
        }).addTo(map);

    
      var layerUrl = "'''+vizID+'''";
    
      var sublayers = [];
    
      cartodb.createLayer(map, layerUrl,{
                title: true,
                description: false,
                search: true,
                tiles_loader: true,
                layer_selector:true,
                cartodb_logo: false,
                legends: true
            })
      .addTo(map)
      .on('done', function(layer) {
        // change the query for the first layer
        var subLayerOptions = {
          //sql: "SELECT * FROM ne_10m_populated_places_simple",
          //cartocss: "#ne_10m_populated_places_simple{marker-fill: #F84F40; marker-width: 8; marker-line-color: white; marker-line-width: 2; marker-clip: false; marker-allow-overlap: true;}"
        }
    
        var sublayer = layer.getSubLayer(0);
    
        sublayer.set(subLayerOptions);
    
        sublayers.push(sublayer);
      }).on('error', function() {
        //log the error
      });
    }'''

    Html_file= open(wd+'js/'+varTheme+'_script.js',"w")
    Html_file.write(js_str)
    Html_file.close()
